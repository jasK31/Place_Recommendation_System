# %%
# Login jas
#pass 1234

# %%
import nltk
from tkinter import *
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
from tkinter import scrolledtext
import random
import numpy as np
import pandas as pd
import os
import gc
from sklearn.model_selection import train_test_split
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings
warnings.filterwarnings('ignore')

# %%
def main():
    
    app = tk.Tk()
    app.geometry('250x135')


    right = Frame(app,bg='grey',height =1000,width=400,bd=5,relief=RIDGE)
    right.pack()


    name_inp = StringVar()
    password_inp = StringVar()
    def enter():
        if name_inp.get() == "jas" and password_inp.get() == "1234":
            app.destroy()
            second_win()
        else:
            messagebox.showinfo("Login","Incorrect Username or Password")
        
    def second_win():
        df = pd.read_csv("dddd.csv",encoding = "latin1", low_memory=False)
        df.dropna(inplace = True)
        secd = Tk()
        secd.geometry('600x300')
        secd.title("Chose ")
        secd.configure(background="grey")
        def logout_t_t_k():
            secd.destroy()
            main()

        def things_to_do():
            secd.destroy()
            t_t_d = Tk()
            t_t_d.geometry('600x500')
            t_t_d.title("things_to_do ")
            def back_t_t_k():
                t_t_d.destroy()
                second_win()
            def Reset():
                cmb.set("")
                comboExample2.set("")
                txtReceipt.delete("1.0",END)


            def get_place():
                df = pd.read_csv("dddd.csv",encoding = "latin1", low_memory=False)
                df.dropna(inplace = True)
                pla = df.loc[(df["Name of City"] == cmb.get())& (df.Cat1 == comboExample2.get()),["Place"]]
                txtReceipt.delete(0.0,"end")
                if pla.empty:
                    messagebox.showinfo("No Place","Sorry this type of category not exists in data ")
                else:
                    for i in pla['Place'].values:
                        
                        txtReceipt.insert("end",f"\n{i}")
                        txtReceipt.see(END)


            Top_t= Frame(t_t_d,width=800,height =100,bd = 5, bg='grey',relief = RIDGE)
            Top_t.pack(side=TOP)
            Center_t= Frame(t_t_d,width=600,height =100,bd = 5, bg='grey',relief = RIDGE)
            Center_t.pack(side=TOP)
            Bot_t= Frame(t_t_d,width=600,height =300,bd = 5, bg='grey',relief = RIDGE)
            Bot_t.pack(side=TOP)

            t_=Label(Top_t,bg='grey',fg='white', text="        Welcome To Place Recommendation Engine        ",font=("bold", 20))
            t_.pack()
            
            #Button(right, padx= 1,bd=5, width = 26,text="Log in", command= enter,relief=RIDGE)
            btnchs=Button(Center_t,padx=15,pady=1,bd=7,font=('arial',8,'bold'),width=16,text='Choose State Below ').grid(row=0,column=0)
            btnchc=Button(Center_t,padx=15,pady=1,bd=7,fg='black',font=('arial',8,'bold'),width=16,text='choose Category Blow',bg='#000000').grid(row=0,column=1)
            btnrst=Button(Center_t,padx=15,pady=1,bd=7,fg='black',font=('arial',8,'bold'),width=16,text='Reset',command=Reset,bg='#000000').grid(row=0,column=2)
            btnext=Button(Center_t,padx=15,pady=1,bd=7,fg='black',font=('arial',8,'bold'),width=16,text='Back',bg='#000000',command=back_t_t_k).grid(row=0,column=3) 
            city = []
            for i in df["Name of City"].unique():
                city.append(i)
            cmb = ttk.Combobox(Center_t, width="14", values=city)
            class TableDropDown(ttk.Combobox):
                def __init__(self, parent):
                    self.current_table = tk.StringVar() # create variable for table
                    ttk.Combobox.__init__(self, parent)#  init widget
                    self.config(textvariable = self.current_table,values = city)
                    #self.current(0) # index of values for current table
                    self.place(x = 500, y = 500, anchor = "w") # place drop down box 
                    #print(cmb.get())
            cmb.grid(row = 2, column = 0)

            d  = []
            #dd = df.loc[(df["Name of City"] == cmb.get()),["Cat1"]]
            for i  in df["Cat1"].unique():
                d.append(i)
                #print(d)
            comboExample2 = ttk.Combobox(Center_t,values=d, width="14")
            class TableDropDown(ttk.Combobox):
                def __init__(self, parent):
                    self.current_table = tk.StringVar() # create variable for table
                    ttk.Combobox.__init__(self, parent)#  init widget
                    self.config(textvariable = self.current_table,values = city)
                    #self.current(0) # index of values for current table
                    self.place(x = 400, y = 400, anchor = "w") # place drop down box 
            comboExample2.grid(row = 2,column = 1)
            
            def t_t_kLogout():
                t_t_d.destroy()
                main()


            btngtplc=Button(Center_t,padx=20,pady=1,bd=7,fg='black',font=('arial',8,'bold'),width=16,text='Get Place',command=get_place,bg='grey').grid(row=2,column=2)
            btnbck=Button(Center_t,padx=20,pady=1,bd=7,fg='black',font=('arial',8,'bold'),width=16,text='Logout',command=t_t_kLogout,bg='grey').grid(row=2,column=3)
            txtReceipt=scrolledtext.ScrolledText(Bot_t,width=74,height=29,bg='grey',fg="black",bd=4,font=('arial',12,'bold'))
            txtReceipt.grid(row=0,column=0)
            t_t_d.resizable(False,False)
            t_t_d.mainloop()


        def thrdwin():
            secd.destroy()
            root = Tk()
            root.geometry('700x500')
            root.title("Recommendations ")
            df = pd.read_csv("dddd.csv",encoding = "latin1", low_memory=False)
            df.dropna(inplace = True)
            root.configure(background="grey")
            #var = StringVar()

            

            def Recommend():
                txtReceip3.delete(0.0,"end")
                try: 
                    ratings_df = pd.read_csv("ratings_small.csv", low_memory=False)
                    links_df = pd.read_csv("link_small.csv", low_memory=False)
                    place_metadata_df = pd.read_csv("dddd.csv",encoding = "latin1", low_memory=False)
                    credits_df = pd.read_csv("credits.csv", low_memory=False)


                    place_metadata_df = place_metadata_df.loc[(place_metadata_df['Name of City'] == comboExample3.get()),:]
                    place_metadata_df.dropna(inplace = True)
                    def get_list(x, l=5):
                        if isinstance(x, list):
                            names = [i['name'] for i in x]
                        #Check if more than l elements exist. If yes, return only first three. If no, return entire list.
                            if len(names) > l:
                                names = names[:l]
                            return names

                    #Return empty list in case of missing/malformed data
                        return []
                    

                    place_metadata_df['genres'] = place_metadata_df['genres'].apply(literal_eval)
                    place_metadata_df['genres'] = place_metadata_df['genres'].apply(get_list)
                    tmp = ratings_df.groupby(['placeId'])['rating'].mean()
                    R = pd.DataFrame({'id':tmp.index, 'R': tmp.values})
                    tmp = ratings_df.groupby(['placeId'])['rating'].count()
                    v = pd.DataFrame({'id':tmp.index, 'v': tmp.values})
                    C = ratings_df['rating'].mean()
                    m_df = place_metadata_df.merge(R, on=['id'])
                    m_df = m_df.merge(v, on=['id'])
                    m_df['C'] = C
                    m= m_df['v'].quantile(0.9)
                    m_df['m'] = m
                    m_df['Main_score']=(m_df['v']/(m_df['v']+m_df['m']))*m_df['R']+(m_df['m']/(m_df['v']+m_df['m']))*m_df['C']
                    m_df['R_x_v'] = m_df['R'] * m_df['v']
                    m_df[['Place','R_x_v']].sort_values(by=['R_x_v'], ascending=False)
                    del tmp
                    gc.collect()

                    tfidf = TfidfVectorizer(stop_words='english',max_features=10000)
                    tokens = m_df[['Place']]
                    tokens['Place'] = tokens['Place'].fillna('')
                    tfidf_matrix = tfidf.fit_transform(tokens['Place'])
                    from sklearn.metrics.pairwise import linear_kernel
                    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
                    indices = pd.Series(tokens.index, index=tokens['Place']).drop_duplicates()
                    def get_recommendations(title, cosine_sim=cosine_sim):
                        idx = indices[title]
                       
                    # similarity scores of all place with that place
                        sim_scores = list(enumerate(cosine_sim[idx]))

                    # sort the places based on the similarity scores
                        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

                    # scores of the 10 most similar places
                        sim_scores = sim_scores[1:11]

                    # place indices
                        place_indices = [i[0] for i in sim_scores]

                    # top 10 most similar place

                        return tokens['Place'].iloc[place_indices]

                    va = get_recommendations(varr.get())
                    
                    for i in va.values:
                        txtReceip3.insert('end',f"\n{i}")
                        
                except ValueError:
                    messagebox.showinfo("ac "," visit another city")
                except KeyError:
                    messagebox.showinfo("No Recommendations yet ", "visit another city")

            def Top_Place():
                txtReceip.delete(0.0,"end")
                ratings_df = pd.read_csv("ratings_small.csv", low_memory=False)
                links_df = pd.read_csv("link_small.csv", low_memory=False)
                place_metadata_df = pd.read_csv("dddd.csv",encoding = "latin1", low_memory=False)
                credits_df = pd.read_csv("credits.csv", low_memory=False)


                place_metadata_df = place_metadata_df.loc[(place_metadata_df['Name of City'] == comboExample3.get()),:]
                place_metadata_df.dropna(inplace = True)
                def get_list(x, l=5):
                    if isinstance(x, list):
                        names = [i['name'] for i in x]
                        #Check if more than l elements exist. If yes, return only first three. If no, return entire list.
                        if len(names) > l:
                            names = names[:l]
                        return names

                #Return empty list in case of missing/malformed data
                    return []

                place_metadata_df['genres'] = place_metadata_df['genres'].apply(literal_eval)
                place_metadata_df['genres'] = place_metadata_df['genres'].apply(get_list)
                tmp = ratings_df.groupby(['placeId'])['rating'].mean()
                R = pd.DataFrame({'id':tmp.index, 'R': tmp.values})
                tmp = ratings_df.groupby(['placeId'])['rating'].count()
                v = pd.DataFrame({'id':tmp.index, 'v': tmp.values})
                C = ratings_df['rating'].mean()
                m_df = place_metadata_df.merge(R, on=['id'])
                m_df = m_df.merge(v, on=['id'])
                m_df['C'] = C
                m= m_df['v'].quantile(0.9)
                m_df['m'] = m
                m_df['Main_score'] = (m_df['v'] / (m_df['v'] + m_df['m'])) * m_df['R'] + (m_df['m'] / (m_df['v'] + m_df['m'])) * m_df['C']
                m_df['R_x_v'] = m_df['R'] * m_df['v']
                m_df[['Place','R_x_v']].sort_values(by=['R_x_v'], ascending=False)
                ma = m_df.loc[(m_df["Name of City"] == comboExample3.get()) & (m_df["R_x_v"] >= 3.5),["Place"]]
                for i in ma['Place'].values:
                    #txtReceip.insert(END,ma)
                    txtReceip.insert(END,f"\n{i}")
                    txtReceip.see(END)


            def reset3():
                varr.set("")
                txtReceip3.delete("1.0",END)
            def Logout_trd():
                root.destroy()
                main()
                

            Top_= Frame(root,width=8000,height =50,bd = 3, bg='grey')
            Top_.pack(side=TOP)

            Top_R= Frame(root,width=8000,height =50,bd = 3, bg='grey',relief = RIDGE)
            Top_R.pack(side=TOP)
            
            Left_R= Frame(root,width=500,height =500,bd = 3, bg='grey',relief = RIDGE)
            Left_R.pack(side=RIGHT)
            Right_R= Frame(root,width=500,height =500,bd = 3, bg='grey',relief = RIDGE)
            Right_R.pack(side=LEFT)

            lblTitle=Label(Top_,font=('arial',16,'bold'),text='Place Recommendation\t\t     ',
                               bg = "grey",fg='gold')
            lblTitle.pack(side=LEFT)
            Logout_trd=Button(Top_,padx=20,pady=1,fg='red',bg='silver',font=('arial',12,'bold')
                                ,width=13,text='Logout',command=Logout_trd).pack(side=RIGHT)

            btnchosseplc=Button(Top_R,padx=20,pady=1,bd=3,fg='black',font=('arial',12,'bold')
                                ,width=13,text='Choose Place to visit :',bg='silver').grid(row=0,column=2)
            
            btnrecomd=Button(Top_R,padx=20,pady=1,fg='black',font=('arial',12,'bold')
                             ,width=13,text="Recommendation",command =Recommend,bg='silver').grid(row=1,column=2)
            varr = tk.StringVar(Top_R)

            e1 =Entry(Top_R,width=13,bd=7,bg='white',textvariable=varr).grid(row = 0, column = 3)
            

            btnrecomd=Button(Top_R,padx=20,pady=1,bd=7,fg='black',font=('arial',12,'bold')
                             ,width=16,text="Reset",command=reset3,bg='grey').grid(row=1,column=3)


            Total=Button(Top_R,padx=40,pady=1,bd=6,font=('arial',12,'bold'),width=13,text='Choose city to visit: ',
                         bg='grey').grid(row=0,column=0)
            
            btnReceipt=Button(Top_R,padx=40,pady=1,bd=6,font=('arial',12,'bold'),width=13,text='Top Place',
                              command=Top_Place,bg='grey').grid(row=0,column=1)

            #ecmd=Button(F,padx=58,pady=1,bd=6,fg='#5BC8AC',font=('arial',8,'bold'),width=1,text='Get Recommend',
                        #bg='#004445').grid(row=2,column=0)
            city = []
            for i in df["Name of City"].unique():
                city.append(i)

            comboExample3 = ttk.Combobox(Top_R,values=city, width="16")
            class TableDropDown(ttk.Combobox):
                def __init__(self, parent):
                    self.current_table = tk.StringVar() # create variable for table
                    ttk.Combobox.__init__(self, parent)#  init widget  
                    self.config(textvariable = self.current_table,values = city)
                    #self.current(0) # index of values for current table
                    self.place(x = 400, y = 400, anchor = "w") # place drop down box 
            comboExample3.grid(row=1,column=0)

            def Reset1():
                comboExample3.set("")
                txtReceip.delete("1.0",END)


            btnReset=Button(Top_R,padx=40,pady=1,bd=4,font=('arial',12,'bold'),width=13,text='Reset', 
                            bg='grey',command=Reset1).grid(row=1,column=1)


            txtReceip3=scrolledtext.ScrolledText(Left_R,width=51,height=24,bg='white',fg="black",bd=4,font=('arial',12,'bold'))
            txtReceip3.pack(side =TOP)


            txtReceip=scrolledtext.ScrolledText(Right_R,width=51,height=24,bg='white',fg="black",bd=4,font=('arial',12,'bold'))
            txtReceip.grid(row=0,column=0)

            root.resizable(False,False)
            root.mainloop()


        canvas = Frame(secd,width=500,height = 200,bd = 5, bg='silver',relief = GROOVE)
        canvas.pack(side = TOP)
        canvas2 = Frame(secd,width=600,height = 300,bd = 5, bg='silver',relief = RIDGE)
        canvas2.pack(side = BOTTOM)
        l = Label(canvas, bg='grey',fg='cyan',width= 70,text="Make your choice",font=("bold", 40))
        l.pack()
        #l2 = Label(canvas2,bg='grey',fg='white',relief=GROOVE, width= 36,text="Click Below",font=("bold", 21))
       # l2.place(x= 3 , y = 16)
        b1 = Button(canvas2 ,bd = 3,command = things_to_do,relief=RAISED,height=2,
                    width=14,text="Things To Do",font=("bold",18))
        b1.place(x =90, y =40)
        
        b2= Button(canvas2,relief=RAISED,height=2,fg='red',
                   width=7,text="Log Out",command=logout_t_t_k,font=("bold", 18))
        b2.place(x =230, y =130)
        
        b3 = Button(canvas2 ,bd = 3,relief=RAISED,height=2 ,command = thrdwin,
                    width=14,text="Recommendation",font=("bold", 18))
        b3.place(x =290, y =40)
        # run it ...
        secd.resizable(False,False)
        secd.mainloop()
        
            
    def destroy():
        app.destroy()
        
    label1 = Label(right,height=3, width = 10,bg='grey',fg='white',font =('slant',10,'bold'),text="Username:",relief= FLAT)
    label1.grid(row=1) 

    label2 = Label(right,height=3,width = 10,bg='grey',fg='white', font =('slant',10,'bold'),text="Password:",relief=FLAT)
    label2.grid(row=2)
    
    label3=Label(right,bg='grey',height=2)
    label3.grid(row=3)

    entry1 = Entry(right,width = 16, textvariable = name_inp)
    entry1.grid(row=1,column=1)

    entry2 = Entry(right,width = 16, textvariable = password_inp,show="*")
    entry2.grid(row=2,column=1)

    exit_btn= Button(right,width=7,bd = 2, text="Exit", command= destroy,relief=RAISED)
    exit_btn.place(x=170,y=82)

    enter_btn = Button(right,bd=2,width = 7,text="Log in", command= enter,relief=RAISED)
    enter_btn.place(x=86,y=82)
    
    app.resizable(False,False)
    app.mainloop()
  

     
main()
